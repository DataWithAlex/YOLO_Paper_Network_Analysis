# %%
#%pip install pybliometrics
#%pip install habanero
#%pip install crossref_commons


import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def get_citations(doi):
    cited_by = []
    try:
        for pub in iterate_publications_as_json(cites=doi):
            cited_by.append(pub)
        return cited_by
    except Exception as e:
        print(f"Error getting citations for {doi}: {e}")
        return []

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [author.get("given") + " " + author.get("family") for author in pub.get("author")] if pub.get("author") else []
    abstract = None  # Crossref often doesn't have abstracts
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        abstract = ab.abstract
        return doi, title, year, authors, abstract
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data[4]:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[4]:  # if no abstract from Crossref, try Scopus
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Add papers that cite the initial paper
    for pub in get_citations(initial_doi):
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[4]:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], initial_doi)

    # Add citations of those papers
    for node in list(G.nodes())[1:]:  # skipping the initial paper
        for pub in get_citations(node):
            paper_data = get_paper_data_from_crossref(pub)
            if not paper_data[4]:
                paper_data = get_paper_data_from_scopus(paper_data[0])
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], node)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1109/CVPR.2016.91 from Scopus: 'NoneType' object is not iterable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 99
#      96     nx.write_graphml(G, "citation_network_El.graphml")
#      98 if __name__ == "__main__":
# ---> 99     main()
#
# Cell In[5], line 76, in main()
#      74 if not paper_data[4]:  # if no abstract from Crossref, try Scopus
#      75     paper_data = get_paper_data_from_scopus(initial_doi)
# ---> 76 add_paper_to_network(G, paper_data)
#      78 # Add papers that cite the initial paper
#      79 for pub in get_citations(initial_doi):
#
# Cell In[5], line 56, in add_paper_to_network(G, paper_data)
#      55 def add_paper_to_network(G, paper_data):
# ---> 56     doi, title, year, authors, abstract = paper_data
#      57     if doi not in G:
#      58         G.add_node(doi, title=title, year=year, authors=authors, abstract=abstract)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx
import lxml

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    try:
        response = cr.works(query=f"doi:{doi}")
        if response.get("message") and response.get("message").get("items"):
            for item in response["message"]["items"]:
                cited_by.append(item)
        return cited_by
    except Exception as e:
        print(f"Error getting citations for {doi}: {e}")
        return []



def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    
    return doi, title, year, authors


def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        return doi, title, year, authors
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str)



def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data:
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Add papers that cite the initial paper
    for pub in get_citations(initial_doi):
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], initial_doi)

    # Add citations of those papers
    for node in list(G.nodes())[1:]:  # skipping the initial paper
        for pub in get_citations(node):
            paper_data = get_paper_data_from_crossref(pub)
            if not paper_data:
                paper_data = get_paper_data_from_scopus(paper_data[0])
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], node)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx
import lxml

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    try:
        response = cr.works(query=f"doi:{doi}")
        if response.get("message") and response.get("message").get("items"):
            for item in response["message"]["items"]:
                cited_by.append(item)
        return cited_by
    except Exception as e:
        print(f"Error getting citations for {doi}: {e}")
        return []



def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    
    return doi, title, year, authors


def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        return doi, title, year, authors
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str)



def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

# ... [previous imports and functions]

def fetch_and_add_to_network(G, doi, depth=2):
    if depth <= 0:
        return

    # Introduce a delay to avoid hitting rate limits
    time.sleep(2)

    # Fetch citations for the given DOI
    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], doi)

        # Recursively fetch citations for the new paper
        fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data:
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Fetch citations recursively for the initial paper
    fetch_and_add_to_network(G, initial_doi, depth=2)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx
import lxml

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 200
    items_per_page = 100  # Adjust as needed

    while True:
        try:
            response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
            if response.get("message") and response.get("message").get("items"):
                items = response["message"]["items"]
                cited_by.extend(items)

                # If less items than expected are returned, it's the last page
                if len(items) < items_per_page:
                    break

                offset += items_per_page
            else:
                break

        except Exception as e:
            print(f"Error getting citations for {doi} at offset {offset}: {e}")
            break

    return cited_by




def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    
    return doi, title, year, authors


def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        return doi, title, year, authors
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str)



def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

# ... [previous imports and functions]

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    # Introduce a delay to avoid hitting rate limits
    time.sleep(2)

    # Fetch citations for the given DOI
    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], doi)

        # Recursively fetch citations for the new paper
        fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data:
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Fetch citations recursively for the initial paper
    fetch_and_add_to_network(G, initial_doi, depth=1)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting citations for 10.1109/CVPR.2016.91 at offset 10000: 400 Client Error: Bad Request for url: https://api.crossref.org/works?query=doi%3A10.1109%2FCVPR.2016.91&offset=10000&rows=100

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx
import lxml

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 50  # Set limit to 50

    try:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            cited_by.extend(items[:50])  # Ensure only 50 items are added

    except Exception as e:
        print(f"Error getting citations for {doi} at offset {offset}: {e}")

    return cited_by





def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    
    return doi, title, year, authors


def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        return doi, title, year, authors
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str)



def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

# ... [previous imports and functions]

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    # Introduce a delay to avoid hitting rate limits
    time.sleep(2)

    # Fetch citations for the given DOI
    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], doi)

        # Recursively fetch citations for the new paper
        fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data:
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Fetch citations recursively for the initial paper
    fetch_and_add_to_network(G, initial_doi, depth=2)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx
import lxml

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

# ... [previous imports]

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    # Check publication year
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    # Check if the title has at least 5 words
    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    # Check if authors are present
    if not pub.get("author"):
        return False

    return True

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000  # Requesting a larger number to filter out and retain 50 valid ones

    try:
        while len(cited_by) < 50:  # Keep fetching until we have 50 valid citations
            response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
            if response.get("message") and response.get("message").get("items"):
                items = response["message"]["items"]
                for item in items:
                    if valid_publication(item):
                        cited_by.append(item)
                        if len(cited_by) >= 50:
                            break
            offset += items_per_page

    except Exception as e:
        print(f"Error getting citations for {doi} at offset {offset}: {e}")

    return cited_by[:50]  # Ensure only 50 items are returned

# ... [rest of the code remains the same]

if __name__ == "__main__":
    main()






def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    
    return doi, title, year, authors


def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        return doi, title, year, authors
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str)



def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data:
            paper_data = get_paper_data_from_scopus(citing_doi)
        add_paper_to_network(G, paper_data)
    G.add_edge(citing_doi, cited_doi)

# ... [previous imports and functions]

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    # Introduce a delay to avoid hitting rate limits
    time.sleep(2)

    # Fetch citations for the given DOI
    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data:
            paper_data = get_paper_data_from_scopus(paper_data[0])
        add_paper_to_network(G, paper_data)
        add_citation_to_network(G, paper_data[0], doi)

        # Recursively fetch citations for the new paper
        fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    # Add initial paper to the network
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data:
        paper_data = get_paper_data_from_scopus(initial_doi)
    add_paper_to_network(G, paper_data)

    # Fetch citations recursively for the initial paper
    fetch_and_add_to_network(G, initial_doi, depth=2)

    # Export the network to .graphml format
    nx.write_graphml(G, "citation_network_El.graphml")

if __name__ == "__main__":
    main()

# %%
import os
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref
from crossref_commons.iteration import iterate_publications_as_json
from crossref_commons.retrieval import get_publication_as_json
from pybliometrics.scopus.exception import Scopus429Error
import time
import networkx as nx

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    try:
        while len(cited_by) < 50:
            response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
            if response.get("message") and response.get("message").get("items"):
                items = response["message"]["items"]
                for item in items:
                    if valid_publication(item):
                        paper_data = get_paper_data_from_crossref(item)
                        if not paper_data[-1]:  # Check if abstract is None
                            paper_data = get_paper_data_from_scopus(paper_data[0])
                        if paper_data[-1]:  # Check if abstract is not None after Scopus fetch
                            cited_by.append(item)
                            if len(cited_by) >= 50:
                                break
            offset += items_per_page

    except Exception as e:
        print(f"Error getting citations for {doi} at offset {offset}: {e}")

    return cited_by[:50]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = []
    if pub.get("author"):
        for author in pub.get("author"):
            given = author.get("given") or ""
            family = author.get("family") or ""
            authors.append(given + " " + family)
    abstract = None
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [au.given_name + " " + au.surname for au in ab.authors]
        abstract = ab.abstract if hasattr(ab, 'abstract') else None
        return doi, title, year, authors, abstract
    except Scopus429Error:
        time.sleep(60)
        return get_paper_data_from_scopus(doi)
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None

def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    abstract = abstract if abstract else "No Abstract"
    if doi and doi not in G:
        G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    if citing_doi not in G:
        paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(citing_doi)
        if paper_data[-1]:  # Check if abstract is not None after Scopus fetch
            add_paper_to_network(G, paper_data)
            G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    time.sleep(2)

    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data[-1]:  # Check if abstract is not None after Scopus fetch
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], doi)

            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"

    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data or not paper_data[-1]:  # Check if data is None or abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data and paper_data[-1]:  # Check if data is not None and abstract is not None after Scopus fetch
        add_paper_to_network(G, paper_data)

    fetch_and_add_to_network(G, initial_doi, depth=2)

    nx.write_graphml(G, "citation_network_El_Abs.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1109/CVPR.2016.91 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting citations for 10.1109/CVPR.2016.91 at offset 0: 'NoneType' object is not subscriptable

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < 50:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= 50:
                        break
        offset += items_per_page

    return cited_by[:50]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)

def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        fetch_and_add_to_network(G, initial_doi, depth=1)
        nx.write_graphml(G, "citation_network_El_Abs.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.hjc.2016.03.002 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/9/1109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medengphy.2016.07.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30338-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/os-2016-41-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.ijbiomac.2016.06.076 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.imbio.2016.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1134/s1064229316100033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cmdc.201600254 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4157/grj.91.176 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/s1473-3099(16)30337-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/s3ge0-yy878 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2109/jcersj2.16140 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-658-07049-6_91 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11340-016-0166-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac4 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1097/acm.0000000000001340 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/10/1211 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac2 from Scopus: The resource specified cannot be found.
# Error getting data for 10.13109/homh.2016.91.10.495 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1017/s0022215116003728 from Scopus: The resource specified cannot be found.

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < 50:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= 50:
                        break
        offset += items_per_page

    return cited_by[:50]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1, max_papers=None):
    if depth <= 0 or (max_papers is not None and len(G) >= max_papers):
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    citations = get_citations(doi)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1, max_papers=max_papers)


def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)

        # Fetch for different depths
        fetch_and_add_to_network(G, initial_doi, depth=1, max_papers=200)
        fetch_and_add_to_network(G, initial_doi, depth=2, max_papers=210)  # 200 from depth 1 + 10 for depth 2
        fetch_and_add_to_network(G, initial_doi, depth=3, max_papers=213)  # 210 from previous depths + 3 for depth 3
        
        nx.write_graphml(G, "citation_network_El_Abs_Depth.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.hjc.2016.03.002 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30338-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/9/1109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medengphy.2016.07.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/os-2016-41-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.ijbiomac.2016.06.076 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.imbio.2016.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1134/s1064229316100033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cmdc.201600254 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30337-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4157/grj.91.176 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/s3ge0-yy878 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2109/jcersj2.16140 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-658-07049-6_91 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11340-016-0166-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1097/acm.0000000000001340 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac4 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1149/ma2016-02/10/1211 from Scopus: The resource specified cannot be found.
# Error getting data for 10.13109/homh.2016.91.10.495 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac2 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1017/s0022215116003728 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.hjc.2016.03.002 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17660/actahortic.1994.377.45 from Scopus: The resource specified cannot be found.
# Error getting data for 10.47749/t/unicamp.1986.17660 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5962/bhl.title.147343 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/9/1109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medengphy.2016.07.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30338-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/os-2016-41-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.imbio.2016.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1134/s1064229316100033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cmdc.201600254 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30337-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/s3ge0-yy878 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2109/jcersj2.16140 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11340-016-0166-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-658-07049-6_91 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1086/688010 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac4 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1149/ma2016-02/10/1211 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac2 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1017/s0022215116003728 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/0004867416671597 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.12989/eas.2016.10.5.1089 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/10/1202 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/transjsme.20-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/transjsme.22-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medcli.2021.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/transjsme.21-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12371-023-00831-y from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11356-022-23589-2 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12371-022-00733-5 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.3390/ma16216885 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.bonr.2021.100911 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000309 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000306 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.bonr.2021.100907 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1891/jnm-d-19-00073 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.heliyon.2019.e02561 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.revpalbo.2023.104942 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1177/136078040501000406 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000407 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000106 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000405 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000408 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000101 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000302 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12665-023-11024-9 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1177/136078040501000206 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000103 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000311 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000307 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1353/dia.2015.0009 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.30630/jam.v10i1.112 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1080/0194262x.2023.2255995 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1126/science.2015.347.6226.347_1080a from Scopus: The resource specified cannot be found.
# Error getting data for 10.5005/jp/books/12785_154 from Scopus: The resource specified cannot be found.
# Error getting data for 10.15363/thinklab.d109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.30630/jam.v10i1.107 from Scopus: The resource specified cannot be found.
# Error getting data for 10.30630/jam.v10i2.106 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/h4y05-k7j13 from Scopus: The resource specified cannot be found.
# Error getting data for 10.30630/jam.v10i2.100 from Scopus: The resource specified cannot be found.
# Error getting data for 10.30630/jam.v10i2.104 from Scopus: The resource specified cannot be found.
# Error getting data for 10.30630/jam.v10i1.108 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1080/0194262x.2023.2250835 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.3940/rina.iccas.2015.02 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/s41567-020-01059-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-73206-6_19 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2023.035135 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2022.020175 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-16759-2_66 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11425-020-1860-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4018/978-1-5225-1837-2.ch050 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.istruc.2021.01.041 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.2320/materia.59.353 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s40995-018-0558-0 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-73206-6_19 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2022.020175 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2023.035135 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-16759-2_66 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11425-020-1860-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4018/978-1-5225-1837-2.ch050 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.istruc.2021.01.041 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.2320/materia.59.353 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/ia/iiad088 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5117/mab.59.21535 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/978-3-030-73206-6_19 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2023.035135 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2022.020175 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-16759-2_66 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11425-020-1860-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4018/978-1-5225-1837-2.ch050 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.istruc.2021.01.041 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.2320/materia.59.353 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s40995-018-0558-0 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17816/kazmj80431 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1515/jura-2019-2280 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.191.4232.1126.a from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/ajhp/52.10.1126a from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.191.4232.1126-b from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.191.4232.1126.b from Scopus: The resource specified cannot be found.
# Error getting data for 10.17485/ijst/2011/v4i10.13 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.142.3596.1126.a from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.123.3208.1126.a from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.196.4294.1126-b from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.196.4294.1126.b from Scopus: The resource specified cannot be found.
# Error getting data for 10.1097/opx.0000000000001807 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/ente.201600464 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.129.3356.1126.a from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1061/ajgeb6.0000338 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1126/science.129.3356.1126.b from Scopus: The resource specified cannot be found.
# Error getting data for 10.2174/266625581404210125121800 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.55415/deep-1995-0002 from Scopus: The resource specified cannot be found.
# Error getting data for 10.15388/problemos.1972.10.5496 from Scopus: The resource specified cannot be found.
# Error getting data for 10.15722/jds.15.10.201710.15 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1452-3981(23)15508-8 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1149/ma2009-02/10/1126 from Scopus: The resource specified cannot be found.
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.4244/eijy14m07_13 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s10955-023-03180-w from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.12677/ojls.2022.106150 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1108/mf-10-2019-636 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1108/mf-02-2023-0094 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1108/mf-07-2019-0382 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1093/ptj/52.10.1118 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/ptj/52.10.1118b from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/ptj/52.10.1118a from Scopus: The resource specified cannot be found.
# Error getting data for 10.21577/1984-6835.20180078 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4314/sa.v22i2.1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1002/cphc.201800403 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/s41598-020-64585-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17816/kazmj80406 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s10157-022-02254-5 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17816/kazmj80408 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1097/gme.0000000000000964 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1038/s41423-020-00537-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.35534/pc.0310127 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/ptj/46.10.1116 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/bf03378504 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/s2213-2600(22)00435-0 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1093/ptj/52.10.1117b from Scopus: The resource specified cannot be found.
# Error getting data for 10.1080/17451000.2017.1336246 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1167/19.10.212a from Scopus: The resource specified cannot be found.
# Error getting data for 10.35400/0038-9692-2022-10-220-22 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/bf03377625 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/mi.2016.132 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5958/2249-7137.2020.01373.7 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/bf03377624 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5005/jp/books/12869_144 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1096/fasebj.10.10.8751712 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1055/s-0036-1589289 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1111/codi.14743 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/9/1109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medengphy.2016.07.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30338-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/os-2016-41-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.ijbiomac.2016.06.076 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.imbio.2016.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1134/s1064229316100033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cmdc.201600254 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4157/grj.91.176 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/s1473-3099(16)30337-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/s3ge0-yy878 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2109/jcersj2.16140 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-658-07049-6_91 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11340-016-0166-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac4 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1097/acm.0000000000001340 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/10/1211 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac2 from Scopus: The resource specified cannot be found.
# Error getting data for 10.13109/homh.2016.91.10.495 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1017/s0022215116003728 from Scopus: The resource specified cannot be found.

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi, limit=50):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < limit:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= limit:
                        break
        offset += items_per_page

    return cited_by[:limit]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1, limit=None):
    if depth <= 0 or (limit is not None and len(G) >= limit):
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    if depth == 1:
        limit = 50
    elif depth == 2:
        limit = 7
    elif depth == 3:
        limit = 3

    citations = get_citations(doi, limit=limit)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            add_citation_to_network(G, paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)


def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        fetch_and_add_to_network(G, initial_doi, depth=3)
        nx.write_graphml(G, "citation_network_El_Abs_Depth_Again.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.hjc.2016.03.002 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17660/actahortic.1994.377.45 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17660/actahortic.1994.377.45 from Scopus: The resource specified cannot be found.
# Error getting data for 10.47749/t/unicamp.1986.17660 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5962/bhl.title.147343 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/9/1109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medengphy.2016.07.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30338-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/os-2016-41-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.imbio.2016.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1134/s1064229316100033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cmdc.201600254 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/s1473-3099(16)30337-1 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/tc-2016-72-ac1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/s3ge0-yy878 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2109/jcersj2.16140 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11340-016-0166-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-658-07049-6_91 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1086/688010 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac4 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1149/ma2016-02/10/1211 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac2 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1017/s0022215116003728 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/0004867416671597 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.12989/eas.2016.10.5.1089 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/10/1202 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/transjsme.20-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/transjsme.22-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.medcli.2021.06.014 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/transjsme.21-00073 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12371-023-00831-y from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s11356-022-23589-2 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12371-022-00733-5 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.3390/ma16216885 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.bonr.2021.100911 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000309 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000306 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.bonr.2021.100907 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1891/jnm-d-19-00073 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.heliyon.2019.e02561 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.revpalbo.2023.104942 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1177/136078040501000406 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000109 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000407 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s12665-023-11024-9 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1177/136078040501000106 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000405 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000408 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000101 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000302 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000206 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000103 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000311 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/136078040501000307 from Scopus: The resource specified cannot be found.
# Error getting data for 10.47749/t/unicamp.1986.17660 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/978-3-030-73206-6_19 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2022.020175 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2023.035135 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-16759-2_66 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11425-020-1860-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4018/978-1-5225-1837-2.ch050 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.istruc.2021.01.041 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.2320/materia.59.353 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s40995-018-0558-0 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-73206-6_19 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2022.020175 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.32604/csse.2023.035135 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/978-3-030-16759-2_66 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11425-020-1860-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4018/978-1-5225-1837-2.ch050 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.istruc.2021.01.041 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.2320/materia.59.353 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5117/mab.59.21535 from Scopus: The resource specified cannot be found.

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi, limit=50):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < limit:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= limit:
                        break
        offset += items_per_page

    return cited_by[:limit]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    # Set the limit based on the depth
    if depth == 1:
        limit = 100
    elif depth == 2:
        limit = 50
    elif depth == 3:
        limit = 3

    citations = get_citations(doi, limit=limit)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            # Connect the citing paper (current one) with the cited one (previous in the loop)
            G.add_edge(paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)


def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        fetch_and_add_to_network(G, initial_doi, depth=3)
        nx.write_graphml(G, "citation_network_El_Abs_Depth_Kachow_Mater.graphml")

if __name__ == "__main__":
    main()
# Out:
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.hjc.2016.03.002 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17660/actahortic.1994.377.45 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s00115-016-0148-3 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17660/actahortic.1994.377.45 from Scopus: The resource specified cannot be found.
# Error getting data for 10.47749/t/unicamp.1986.17660 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11606-016-3822-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5962/bhl.title.147343 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.jiac.2016.07.010 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.surg.2020.08.011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02
from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/med/9780190497774.003.0002 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1099/acmi.0.000484.v1.3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.17918/etd-4350 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1167/18.10.1260 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1001/jamadermatol.2016.3453 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.brs.2017.01.536 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/med/9780190497774.003.0015 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1167/18.10.1242 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1167/17.10.479 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1093/med/9780190497774.003.0017 from Scopus: The resource specified cannot be found.
# Error getting data for 10.59350/7g8db-0m725 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1177/0004867416671597 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1504/ijhrcs.2023.127638 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s10955-023-03180-w from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5488/cmp.26.16701 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1089/jpm.2023.0455 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1167/19.10.212a from Scopus: The resource specified cannot be found.
# Error getting data for 10.35400/0038-9692-2022-10-220-22 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1089/jpm.2023.0443 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1089/jpm.2023.0451 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1097/01.tp.0000945644.71580.d1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.57262/die/1356038589 from Scopus: The resource specified cannot be found.
# Error getting data for 10.11606/issn.2447-7125.v5i0p5-10 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1355/9789814818155-015 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/esd-2023-4-rc3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.2352/cic.2002.10.1.art00044 from Scopus: The resource specified cannot be found.
# Error getting data for 10.15196/rs100203 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s40515-022-00223-9 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.radcr.2023.08.003 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.17104/9783406797361-10 from Scopus: The resource specified cannot be found.
# Error getting data for 10.51202/0042-1758-2023-10-10 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/s41598-020-64527-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s40515-022-00224-8 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1080/14790718.2022.2164583 from Scopus: The resource specified cannot be found.
# Error getting data for 10.17504/protocols.io.kxygx9d8wg8j/v1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s11605-023-05810-w from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1007/s00586-023-07850-x from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/chin.197919122 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s00586-023-07959-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1016/j.engappai.2023.105971 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1097/01.asm.0000989864.77606.c3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/s41598-023-37394-5 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.46630/ibhc.2023 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1136/bmjpo-2023-asped.10 from Scopus: The resource specified cannot be found.
# Error getting data for 10.4236/oalib.1110781 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s35128-023-1967-0 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1016/j.jamda.2023.04.012 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1167/18.10.990 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1038/s41598-020-60713-z from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.3917/liso.1341.0010 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s15005-023-3429-y from Scopus: The resource specified cannot be found.
# Error getting data for 10.15722/jds.15.10.201710.15 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5771/0030-6444-2011-3-322 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1136/bmjoq-2023-iss.10 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s00586-023-07960-6 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1021/acs.macromol.3c00176 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.4236/oalib.1110740 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1007/s15006-023-2670-0 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.12989/eas.2016.10.5.1089 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1149/ma2016-02/10/1202 from Scopus: The resource specified cannot be found.
# Error getting data for 10.5194/tc-2016-72-ac3 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0016 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0046 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0078 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0051 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0061 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0011 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0091 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1111/anae.14433 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cpz1.304 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0068 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0045 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0025 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0058 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0103 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0006 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0055 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0102 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0033 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0026 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.5194/bg-2017-10-rc1 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0024 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1002/cpz1.581 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.1299/jamdsm.2016jamdsm0096 from Scopus: 'NoneType' object is not iterable
# Error getting data for 10.19083/tesis/624208 from Scopus: The resource specified cannot be found.
# Error getting data for 10.1299/jamdsm.2016jamdsm0052 from Scopus: 'NoneType' object is not iterable

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi, limit=50):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < limit:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= limit:
                        break
        offset += items_per_page

    return cited_by[:limit]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    # Set the limit based on the depth
    if depth == 1:
        limit = 100
    elif depth == 2:
        limit = 50
    elif depth == 3:
        limit = 3

    citations = get_citations(doi, limit=limit)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            # Connect the citing paper (current one) with the cited one (previous in the loop)
            G.add_edge(paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)


def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        fetch_and_add_to_network(G, initial_doi, depth=3)
        nx.write_graphml(G, "citation_network_El_Abs_Depth_Kachow_Mater.graphml")

if __name__ == "__main__":
    main()

# %%
import os
import requests
import time
import networkx as nx
from pybliometrics.scopus import AbstractRetrieval
from habanero import Crossref

API_KEY = "8a456d9c37dfee8ad35feabdb6d73bac"
os.environ["SCOPUS_API_KEY"] = API_KEY

def get_abstract_from_semanticscholar(doi):
    url = f"https://api.semanticscholar.org/v1/paper/{doi}"
    response = requests.get(url)
    data = response.json()
    return data.get('abstract')

def get_paper_by_doi(doi):
    cr = Crossref()
    return cr.works(ids=doi).get("message")

def valid_publication(pub):
    """Check if the publication meets the given requirements."""
    year = pub.get("created").get("date-parts")[0][0]
    if year < 2016:
        return False

    title = pub.get("title")[0] if pub.get("title") else ""
    if len(title.split()) < 5:
        return False

    if not pub.get("author"):
        return False

    return True

def get_citations(doi, limit=50):
    cited_by = []
    cr = Crossref()
    offset = 0
    items_per_page = 1000

    while len(cited_by) < limit:
        response = cr.works(query=f"doi:{doi}", offset=offset, limit=items_per_page)
        if response.get("message") and response.get("message").get("items"):
            items = response["message"]["items"]
            for item in items:
                if valid_publication(item):
                    cited_by.append(item)
                    if len(cited_by) >= limit:
                        break
        offset += items_per_page

    return cited_by[:limit]

def get_paper_data_from_crossref(pub):
    doi = pub.get("DOI")
    title = pub.get("title")[0] if pub.get("title") else None
    year = pub.get("created").get("date-parts")[0][0]
    authors = [f"{author.get('given', '')} {author.get('family', '')}" for author in pub.get("author", [])]
    abstract = get_abstract_from_semanticscholar(doi)
    return doi, title, year, authors, abstract

def get_paper_data_from_scopus(doi):
    try:
        ab = AbstractRetrieval(doi, view="META")
        title = ab.title
        year = ab.coverDate.split("-")[0]
        authors = [f"{au.given_name} {au.surname}" for au in ab.authors]
        abstract = get_abstract_from_semanticscholar(doi)
        return doi, title, year, authors, abstract
    except Exception as e:
        print(f"Error getting data for {doi} from Scopus: {e}")
        return None, None, None, None, None  # Return tuple with None values


def add_paper_to_network(G, paper_data):
    doi, title, year, authors, abstract = paper_data
    if not abstract:  # Check if abstract is available
        return
    authors_str = "; ".join(authors) if authors else ""
    title = title if title else "Unknown Title"
    year = year if year else "Unknown Year"
    G.add_node(doi, title=title, year=year, authors=authors_str, abstract=abstract)

def add_citation_to_network(G, citing_doi, cited_doi):
    paper_data = get_paper_data_from_crossref(get_publication_as_json(citing_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(citing_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        G.add_edge(citing_doi, cited_doi)

def fetch_and_add_to_network(G, doi, depth=1):
    if depth <= 0:
        return

    time.sleep(2)  # Introduce a delay to avoid hitting rate limits

    # Set the limit based on the depth
    if depth == 1:
        limit = 300
    elif depth == 2:
        limit = 100
    elif depth == 10:
        limit = 3

    citations = get_citations(doi, limit=limit)
    for pub in citations:
        paper_data = get_paper_data_from_crossref(pub)
        if not paper_data[-1]:  # Check if abstract is None
            paper_data = get_paper_data_from_scopus(paper_data[0])
        if paper_data and paper_data[-1]:  # Check if paper_data and abstract are not None
            add_paper_to_network(G, paper_data)
            # Connect the citing paper (current one) with the cited one (previous in the loop)
            G.add_edge(paper_data[0], doi)
            fetch_and_add_to_network(G, paper_data[0], depth=depth-1)


def main():
    G = nx.DiGraph()
    initial_doi = "10.1109/CVPR.2016.91"
    paper_data = get_paper_data_from_crossref(get_paper_by_doi(initial_doi))
    if not paper_data[-1]:  # Check if abstract is None
        paper_data = get_paper_data_from_scopus(initial_doi)
    if paper_data[-1]:  # Check if abstract is not None after fetching
        add_paper_to_network(G, paper_data)
        fetch_and_add_to_network(G, initial_doi, depth=3)
        nx.write_graphml(G, "citation_network_El_Abs_Depth_Kachow_Mater_Halloween.graphml")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[32], line 131
#     128         nx.write_graphml(G, "citation_network_El_Abs_Depth_Kachow_Mater_Halloween.graphml")
#     130 if __name__ == "__main__":
# --> 131     main()
#
# Cell In[32], line 127, in main()
#     125 if paper_data[-1]:  # Check if abstract is not None after fetching
#     126     add_paper_to_network(G, paper_data)
# --> 127     fetch_and_add_to_network(G, initial_doi, depth=3)
#     128     nx.write_graphml(G, "citation_network_El_Abs_Depth_Kachow_Mater_Halloween.graphml")
#
# Cell In[32], line 107, in fetch_and_add_to_network(G, doi, depth)
#     104 elif depth == 10:
#     105     limit = 3
# --> 107 citations = get_citations(doi, limit=limit)
#     108 for pub in citations:
#     109     paper_data = get_paper_data_from_crossref(pub)
#
# UnboundLocalError: local variable 'limit' referenced before assignment

# %%
def add_edges_for_all_nodes(G):
    for node in G.nodes():
        # Check if any existing nodes cite this node
        for other_node in G.nodes():
            if other_node == node:
                continue  # Skip checking the same node

            # Check if `other_node` cites `node`
            citations_of_other_node = get_citations(other_node, limit=1000)
            cited_dois = [pub.get("DOI") for pub in citations_of_other_node]
            if node in cited_dois and not G.has_edge(other_node, node):
                G.add_edge(other_node, node)

            # Check if `node` cites `other_node`
            citations_of_node = get_citations(node, limit=1000)
            cited_dois_by_node = [pub.get("DOI") for pub in citations_of_node]
            if other_node in cited_dois_by_node and not G.has_edge(node, other_node):
                G.add_edge(node, other_node)

add_edges_for_all_nodes(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 20
#      17             if other_node in cited_dois_by_node and not G.has_edge(node, other_node):
#      18                 G.add_edge(node, other_node)
# ---> 20 add_edges_for_all_nodes(G)
#
# NameError: name 'G' is not defined

# %%
# %pip install lxml
# Out:
# Requirement already satisfied: lxml in ./venv/lib/python3.9/site-packages (4.9.3)
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the '/Users/alexsciuto/Library/Mobile Documents/com~apple~CloudDocs/DataWithAlex/MSDA Classes/Network_Science/YOLO_Paper_Network_Analysis/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
